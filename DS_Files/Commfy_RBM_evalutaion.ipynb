# %% [markdown]
# # Ruled Based Model
# ### Hey Together,
# Welcome to the notebook for the ruled based model of commfy.
#
#
# ## Part 1: Import libarys

# %%
import random
from random import randint
import requests, json
import pandas as pd
from datetime import datetime, timezone
import pytz
import numpy as np
import config
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Part 2: Gather input
# There is the option to use the function input_generator() or generate_multi_input(a) whenever you need it.

# %%
## auto generated input:
def input_generator():
    location_list=('Rom','Rio de Janeiro','Barcelona','Singapore','Moskau','Melbourne', 'Kathmandu') # example list 
    location=location_list[randint(0,6)]
    time=datetime.now(pytz.timezone('Europe/Berlin')).replace(tzinfo=None)##no timezone for better work through
    time=time.replace(hour=randint(time.hour,23))
    heaviness_of_trip=randint(1,3)
    if heaviness_of_trip==1: heaviness_of_trip="easy"
    if heaviness_of_trip==2: heaviness_of_trip="normal"
    if heaviness_of_trip==3: heaviness_of_trip="hard"
    heat_preference=randint(-5,5)
    sex=randint(1,3)
    if sex==1: sex="m"
    if sex==2: sex="f"
    if sex==3: sex="d"
    df=pd.DataFrame({
    "location" : [location],
    "time": [time], 
    "heaviness_of_trip": [heaviness_of_trip], 
    "heat_preference" : [heat_preference],
    "sex": [sex]
    })
    return df

# %%
#test input generator
print(input_generator().to_json())
input_generator()
# Out:
# {"location":{"0":"Berlin"},"time":{"0":1643241501935},"heaviness_of_trip":{"0":"hard"},"heat_preference":{"0":-5},"sex":{"0":"d"}}
#   location                       time heaviness_of_trip  heat_preference sex
# 0   Moskau 2022-01-26 21:58:21.955655            normal                2   m

# %%
#autogenerate DataFrame with multiple input
def generate_multi_input(a):
    df=input_generator()
    for t in range(a-1): #a Trips today (it is asking for one person, so the sex, the heat preference and the ocation ist not changing)
        df=df.append(input_generator(),ignore_index = True)
        df.at[t+1,'location']=df['location'].iloc[0]
        df.at[t+1,'heat_preference']=df['heat_preference'].iloc[0]
        df.at[t+1,'sex']=df['sex'].iloc[0]
    return df

# %%
#test data with json input
a=generate_multi_input(4)
print(a)
a=a.to_json(orient="index",date_format='iso')
print(a)
json_inp= pd.read_json(a, orient='index',convert_dates=['time'])   
print(json_inp)
# Out:
#    location                       time heaviness_of_trip  heat_preference sex
# 0  Freiburg 2022-01-26 18:58:22.320024              hard                2   d
# 1  Freiburg 2022-01-26 21:58:22.322018              hard                2   d
# 2  Freiburg 2022-01-26 20:58:22.335982              hard                2   d
# 3  Freiburg 2022-01-26 20:58:22.350267              easy                2   d
# {"0":{"location":"Freiburg","time":"2022-01-26T18:58:22.320Z","heaviness_of_trip":"hard","heat_preference":2,"sex":"d"},"1":{"location":"Freiburg","time":"2022-01-26T21:58:22.322Z","heaviness_of_trip":"hard","heat_preference":2,"sex":"d"},"2":{"location":"Freiburg","time":"2022-01-26T20:58:22.335Z","heaviness_of_trip":"hard","heat_preference":2,"sex":"d"},"3":{"location":"Freiburg","time":"2022-01-26T20:58:22.350Z","heaviness_of_trip":"easy","heat_preference":2,"sex":"d"}}
#    location                             time heaviness_of_trip  \
# 0  Freiburg 2022-01-26 18:58:22.320000+00:00              hard
# 1  Freiburg 2022-01-26 21:58:22.322000+00:00              hard
# 2  Freiburg 2022-01-26 20:58:22.335000+00:00              hard
# 3  Freiburg 2022-01-26 20:58:22.350000+00:00              easy
#
#    heat_preference sex
# 0                2   d
# 1                2   d
# 2                2   d
# 3                2   d

# %%
b={"0":{"location":"Freiburg"},"1":{"time":"2022-01-23T23:09:32.856Z"},"2":{"location":"Freiburg","time":"2022-01-23T22:09:32.867Z","heaviness_of_trip":"easy","heat_preference":-2,"sex":"m"},"3":{"location":"Freiburg","time":"2022-01-23T17:09:32.878Z","heat_preference":-2,"sex":"m"}}
c=json.dumps(b)
print(c)
json_inp= pd.read_json(c, orient='index',convert_dates=['time'])   
print(json_inp)
# Out:
# {"0": {"location": "Freiburg"}, "1": {"time": "2022-01-23T23:09:32.856Z"}, "2": {"location": "Freiburg", "time": "2022-01-23T22:09:32.867Z", "heaviness_of_trip": "easy", "heat_preference": -2, "sex": "m"}, "3": {"location": "Freiburg", "time": "2022-01-23T17:09:32.878Z", "heat_preference": -2, "sex": "m"}}
#    location                             time heaviness_of_trip  \
# 0  Freiburg                              NaT               NaN
# 2  Freiburg 2022-01-23 22:09:32.867000+00:00              easy
# 3  Freiburg 2022-01-23 17:09:32.878000+00:00               NaN
# 1       NaN 2022-01-23 23:09:32.856000+00:00               NaN
#
#    heat_preference  sex
# 0              NaN  NaN
# 2             -2.0    m
# 3             -2.0    m
# 1              NaN  NaN

# %% [markdown]
# <hr style="border:2px solid gray"> </hr>
#
# ## Part 3: Data cleaning
# Go through the Dataframe and check if there is non values or wild data.
# 1. if heat preference is empty--> 0
# 2. if sex is empty --> female
# 3. if time is empty --> now timestamp
# 4. if heavines of trip is empty --> normal
# 5. if location is empty --> berlin

# %%
def input_cleaning(df):
    df['heat_preference'] = df['heat_preference'].fillna(0)
    df['time'] = df['time'].fillna(datetime.now(pytz.timezone('Europe/Berlin')).replace(tzinfo=None))
    df['sex'] = df['sex'].fillna('d')
    df['heaviness_of_trip'] = df['heaviness_of_trip'].fillna('normal')
    df['location'] = df['location'].fillna('Berlin')
    return df

# %%
input_cleaning(json_inp)
print(json_inp)
# Out:
#    location                              time heaviness_of_trip  \
# 0  Freiburg        2022-01-26 18:58:22.977480            normal
# 2  Freiburg  2022-01-23 22:09:32.867000+00:00              easy
# 3  Freiburg  2022-01-23 17:09:32.878000+00:00            normal
# 1    Berlin  2022-01-23 23:09:32.856000+00:00            normal
#
#    heat_preference sex
# 0              0.0   d
# 2             -2.0   m
# 3             -2.0   m
# 1              0.0   d

# %% [markdown]
# <hr style="border:2px solid gray"> </hr>
#
# ## Part 4: Further data collection
# Weather(df) function to get from location and the time the weather data.

# %%
def weather(df):
    # base_url variable to store url
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    future_url="https://api.openweathermap.org/data/2.5/forecast?"
    df['weather']=None
    df['temperature']=None
    #for every row in the pandas:
    for i in range(len(df.index)) :

        # Give city name
        city_name = df['location'].iloc[i]
        df_time=df['time'].iloc[i].replace(tzinfo=None)
        now=datetime.now(pytz.timezone('Europe/Berlin')).replace(tzinfo=None)
        # complete_url variable to store
        # complete url address
        complete_current_url = base_url + "appid=" + config.api_key + "&q=" + city_name + "&units=metric"
        complete_future_url= future_url + "q=" + city_name + "&appid=" + config.api_key + "&units=metric"
        # return response object
        response = requests.get(complete_current_url).json() #response for current time
        response_future = requests.get(complete_future_url).json() # response of weather (in 3 hour timeframes)
        time_forecast=datetime.strptime(response_future['list'][0]['dt_txt'],'%Y-%m-%d %H:%M:%S')
        time_forecast2=datetime.strptime(response_future['list'][1]['dt_txt'],'%Y-%m-%d %H:%M:%S')
        # json method of response object
        # convert json format data into
        # python format data
        if (abs((df_time-now).total_seconds()) <abs((time_forecast-df_time).total_seconds()))&(abs((df_time-now).total_seconds()) <abs((time_forecast2-df_time).total_seconds())): #is the time closer to now then to any of the future forecast
            df.at[i,'weather']=response['weather'][0]['main']
            df.at[i,'temperature']=response['main']['temp']
            df.at[i,'windspeed']=response['wind']['speed']
        else:
            for a in range(10): # looks up to 30 hours in the future
                time_forecast=datetime.strptime(response_future['list'][a]['dt_txt'],'%Y-%m-%d %H:%M:%S')
                substrakt=time_forecast-df_time
                if abs(substrakt.total_seconds())<5400: ## Forecast is just every 3 hours, so it is always taking the closest one
                    df.at[i,'weather']=response_future['list'][a]['weather'][0]['main']
                    df.at[i,'temperature']=response_future['list'][a]['main']['temp']
                    df.at[i,'windspeed']=response_future['list'][a]['wind']['speed']
                    break   
    return df

# %%
#weather test
#two dataframes (one with just 1 input, and one with 6 input Trips)
test=weather(input_generator())
len(test.index)
test.to_json()
print(test.to_json())
print(test)
test2=weather(generate_multi_input(20))
test2.head()
# Out:
# {"location":{"0":"Hamburg"},"time":{"0":1643230703148},"heaviness_of_trip":{"0":"normal"},"heat_preference":{"0":-5},"sex":{"0":"m"},"weather":{"0":"Clouds"},"temperature":{"0":4.28},"windspeed":{"0":5.92}}
#   location                       time heaviness_of_trip  heat_preference sex  \
# 0  Hamburg 2022-01-26 20:58:23.148801            normal               -5   m
#
#   weather temperature  windspeed
# 0  Clouds        4.28       5.92
#    location                       time heaviness_of_trip  heat_preference sex  \
# 0  Freiburg 2022-01-26 23:58:23.600754              hard                0   m
# 1  Freiburg 2022-01-26 18:58:23.602746              easy                0   m
# 2  Freiburg 2022-01-26 22:58:23.612736              hard                0   m
# 3  Freiburg 2022-01-26 20:58:23.621696              easy                0   m
# 4  Freiburg 2022-01-26 23:58:23.631668              hard                0   m
#
#   weather temperature  windspeed
# 0  Clouds       -1.53       1.38
# 1     Fog       -1.28       1.03
# 2  Clouds       -1.53       1.38
# 3  Clouds       -1.35       1.41
# 4  Clouds       -1.53       1.38

# %% [markdown]
# Data visualisation:

# %%
plt.figure(figsize=(50, 4))
a = sns.boxplot(x='time', y='temperature',data=test2.sort_values(by='time'))

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='time', y='temperature',data=test2.sort_values(by='time'))
plt.title("Scatterplot")
# Out:
# Text(0.5, 1.0, 'Scatterplot')

# %% [markdown]
# <hr style="border:2px solid gray"> </hr>
#
# ## Part 5: Define the model
# Function add_dummy(df) for test purposes only.<p>
# Decision trees defining the output of this model.<p>
# All functions have Dataframes as input and add new columns to it and return the bigger Dataframe.

# %%
def t_p_s_h(df,i):
    red=0.#reducing parameter
    if df['sex'].iloc[i]=='f':
        red=2.
    heaviness=0.
    if df['heaviness_of_trip'].iloc[i]=='hard':
        heaviness=2.
    else:
        if df['heaviness_of_trip'].iloc[i]=='easy':
            heaviness=-2.
    t_p_s_h=float(df['temperature'].iloc[i])+float(df['heat_preference'].iloc[i])-red+heaviness #t_p_s = temperature_perception and sex and heaviness
    return t_p_s_h

# %%
def add_dummy(df):
    df['headwear']=1
    df['sunglasses']=0
    df['neck']=1
    df['singlet']=0
    df['shirt']=0
    df['upper_body_second_layer']=1
    df['upper_body_third_layer']=1
    df['upper_body_outer_layer']=1
    df['hands']=1
    df['raintrousers']=0
    df['socks']=1
    df['shoes']=1
    for i in range(len(df.index)):
        df.at[i,'headwear']=randint(1,4)
        df.at[i,'sunglasses']=randint(0,1)
        df.at[i,'neck']=randint(1,3)
        df.at[i,'singlet']=randint(0,1)
        df.at[i,'shirt']=randint(0,1)
        df.at[i,'upper_body_second_layer']=randint(1,3)
        df.at[i,'upper_body_third_layer']=randint(1,3)
        df.at[i,'upper_body_outer_layer']=randint(1,5)
        df.at[i,'hands']=randint(1,3)
        df.at[i,'raintrousers']=randint(0,1)
        df.at[i,'socks']=randint(1,2)
        df.at[i,'shoes']=randint(1,3)
    return df

# %%
##todo implement the logic of the decision tree
##headwear decisiontree
def headwear(df):
   df['headwear']=3
   for i in range(len(df.index)):
      if t_p_s_h(df,i)>10:   # above 10 degrees no headwear beside the helmet
            df.at[i,'headwear']=1
      else:
         if t_p_s_h(df,i)>2:
            df.at[i,'headwear']=2
   return df

# %%
## sunglasses decisiontree
def sunglasses(df):
    df['sunglasses']=0
    for i in range(len(df.index)):
        if df['weather'].iloc[i]=='Clear':  # the only split is if it is sunny (clear) or not
            df.at[i,'sunglasses']=1
    return df

# %%
## neck decision tree
def neck(df):
    
    df['neck']=3
    for i in range(len(df.index)):
        if t_p_s_h(df,i)>22:   # above 22 degrees no buff
            df.at[i,'neck']=1
        else :
            if t_p_s_h(df,i)>15:
                if (df['weather'].iloc[i]=='Rain')|(df['windspeed'].iloc[i]>15): # above 15 degrees and windy or rainy buff, else no buff
                    df.at[i,'neck']=2
                else :
                    df.at[i,'neck']=1
            else :
                if (t_p_s_h(df,i)>0) & (df['weather'].iloc[i]=='Clear'): # above 0 dgrees and sunny bufff and the rest gonna be warm scarf
                    df.at[i,'neck']=2
    return df

# %%
##todo implement the logic of the decision tree
##singlet decisiontree
def inner_layer(df):
    df['shirt']=0
    df['singlet']=0
    for i in range(len(df.index)):
        if t_p_s_h(df,i)>10: # at 10 degrees is the split above we wear shirts under we wear a singlet
            df.at[i,'shirt']=1
        else:
            df.at[i,'singlet']=1
    
    return df

# %%
##todo implement the logic of the decision tree
##upper_body_second_layer decisiontree
def upper_body_outer_layers(df):
    df['upper_body_second_layer']=3
    df['upper_body_third_layer']=3
    df['upper_body_outer_layer']=5
    for i in range(len(df.index)):
        if t_p_s_h(df,i)>25:
            df.at[i,'upper_body_second_layer']=1
            df.at[i,'upper_body_third_layer']=1
            df.at[i,'upper_body_outer_layer']=1
        else:
            if t_p_s_h(df,i)>20:
                if df['weather'].iloc[i]=='Rain':
                    df.at[i,'upper_body_second_layer']=2
                    df.at[i,'upper_body_third_layer']=1
                    df.at[i,'upper_body_outer_layer']=3
                else:
                    df.at[i,'upper_body_second_layer']=2
                    df.at[i,'upper_body_third_layer']=1
                    df.at[i,'upper_body_outer_layer']=1
            else:
                if t_p_s_h(df,i)>10:
                    if df['weather'].iloc[i]=='Rain':
                        df.at[i,'upper_body_second_layer']=3
                        df.at[i,'upper_body_third_layer']=1
                        df.at[i,'upper_body_outer_layer']=4
                    else:
                        df.at[i,'upper_body_second_layer']=2
                        df.at[i,'upper_body_third_layer']=2
                        df.at[i,'upper_body_outer_layer']=1
                else:
                    if t_p_s_h(df,i)>0:
                        if df['weather'].iloc[i]=='Clear':
                            df.at[i,'upper_body_second_layer']=2
                            df.at[i,'upper_body_third_layer']=2
                            df.at[i,'upper_body_outer_layer']=3
                        else:
                            df.at[i,'upper_body_second_layer']=3
                            df.at[i,'upper_body_third_layer']=1
                            df.at[i,'upper_body_outer_layer']=5
                    else:
                        if t_p_s_h(df,i)>-5:
                            df.at[i,'upper_body_second_layer']=3
                            df.at[i,'upper_body_third_layer']=2
                            df.at[i,'upper_body_outer_layer']=3
    return df

# %%
##todo implement the logic of the decision tree
##hands decisiontree
def hands(df):
    df['hands']=3
    for i in range(len(df.index)):
        if t_p_s_h(df,i)>10: # first split at 10 degrees , we recommend no handwear.
            df.at[i,'hands']=1
        else:
            if (t_p_s_h(df,i)>7):
                if(df['windspeed'].iloc[i]>15):
                    df.at[i,'hands']=2
                else:
                    df.at[i,'hands']=1
            else:
                if (t_p_s_h(df,i)>0):
                    df.at[i,'hands']=2
    return df

# %%
##todo implement the logic of the decision tree
##raintrousers decisiontree
def raintrousers(df):
    df['raintrousers']=0
    for i in range(len(df.index)):
        if t_p_s_h(df,i)<17: # first split at 17 degrees , if it is less than 17 and raining we recommend to wear raintrosers.
            if df['weather'].iloc[i]=='Rain':
                df.at[i,'raintrousers']=1
    return df

# %%
##todo implement the logic of the decision tree
##socks decisiontree
def socks(df):
    df['socks']=3
    for i in range(len(df.index)):
        if t_p_s_h(df,i)>22:   # above 22 and rainy will give socks
            if df['weather'].iloc[i]=='Rain':
                df.at[i,'socks']=2
            else:
                if df['sex'].iloc[i]=='f': # above 22  and no rain and female witout socks for male with socks
                    df.at[i,'socks']=1
                else:
                    df.at[i,'socks']=2
        else:
            if t_p_s_h(df,i)>0:       # above 0 normal socks under 0 warm socks
                df.at[i,'socks']=2
    return df

# %%
##todo implement the logic of the decision tree
##shoes decisiontree
def shoes(df):
    df['shoes']=3
    for i in range(len(df.index)):
        if t_p_s_h(df,i)>22:   # above 22 degree and rain low shoes
            if df['weather'].iloc[i]=='Rain':
                df.at[i,'shoes']=2
            else:
                    df.at[i,'shoes']=1   #above 22 summer shoes
        else:
            if t_p_s_h(df,i)>7:          # above 7 and rainy --> rainshoes , if not rainy then normal shoes      if under 7 degrees then boots
                if df['weather'].iloc[i]=='Rain':
                    df.at[i,'shoes']=4
                else:
                    df.at[i,'shoes']=2

    return df

# %%
##summing up the decision trees into 1 list
def get_clothing_output_rbm(df):
    headwear(df)
    sunglasses(df)
    neck(df)
    inner_layer(df)
    upper_body_outer_layers(df)
    hands(df)
    raintrousers(df)
    socks(df)
    shoes(df)
    #df['control']=0
    #for i in range(len(df.index)):
    #   df.at[i,'control']=t_p_s_h(df,i)
    return df

# %%
#test the model
test3=weather(generate_multi_input(20))
get_clothing_output_rbm(test3)
# Out:
#    location                       time heaviness_of_trip  heat_preference sex  \
# 0   München 2022-01-26 22:58:33.269031              hard               -4   m
# 1   München 2022-01-26 19:58:33.271025              easy               -4   m
# 2   München 2022-01-26 21:58:33.280002              hard               -4   m
# 3   München 2022-01-26 22:58:33.287981              hard               -4   m
# 4   München 2022-01-26 23:58:33.293970              hard               -4   m
# 5   München 2022-01-26 21:58:33.300947              hard               -4   m
# 6   München 2022-01-26 21:58:33.310922              easy               -4   m
# 7   München 2022-01-26 18:58:33.318898              hard               -4   m
# 8   München 2022-01-26 19:58:33.327873              hard               -4   m
# 9   München 2022-01-26 22:58:33.341837              hard               -4   m
# 10  München 2022-01-26 23:58:33.352807            normal               -4   m
# 11  München 2022-01-26 21:58:33.359789              easy               -4   m
# 12  München 2022-01-26 20:58:33.365772              hard               -4   m
# 13  München 2022-01-26 23:58:33.372798              easy               -4   m
# 14  München 2022-01-26 22:58:33.378779              easy               -4   m
# 15  München 2022-01-26 20:58:33.386757            normal               -4   m
# 16  München 2022-01-26 22:58:33.404711              easy               -4   m
# 17  München 2022-01-26 23:58:33.410698              hard               -4   m
# 18  München 2022-01-26 21:58:33.417676              easy               -4   m
# 19  München 2022-01-26 22:58:33.435628              hard               -4   m
#
#    weather temperature  windspeed  headwear  sunglasses  neck  shirt  singlet  \
# 0   Clouds       -1.82       1.47         3           0     3      0        1
# 1   Clouds       -0.43       0.89         3           0     3      0        1
# 2   Clouds       -0.77       2.03         3           0     3      0        1
# 3   Clouds       -1.82       1.47         3           0     3      0        1
# 4   Clouds       -1.82       1.47         3           0     3      0        1
# 5   Clouds       -0.77       2.03         3           0     3      0        1
# 6   Clouds       -0.77       2.03         3           0     3      0        1
# 7   Clouds       -0.43       0.89         3           0     3      0        1
# 8   Clouds       -0.43       0.89         3           0     3      0        1
# 9   Clouds       -1.82       1.47         3           0     3      0        1
# 10  Clouds       -1.82       1.47         3           0     3      0        1
# 11  Clouds       -0.77       2.03         3           0     3      0        1
# 12  Clouds       -0.77       2.03         3           0     3      0        1
# 13  Clouds       -1.82       1.47         3           0     3      0        1
# 14  Clouds       -1.82       1.47         3           0     3      0        1
# 15  Clouds       -0.77       2.03         3           0     3      0        1
# 16  Clouds       -1.82       1.47         3           0     3      0        1
# 17  Clouds       -1.82       1.47         3           0     3      0        1
# 18  Clouds       -0.77       2.03         3           0     3      0        1
# 19  Clouds       -1.82       1.47         3           0     3      0        1
#
#     upper_body_second_layer  upper_body_third_layer  upper_body_outer_layer  \
# 0                         3                       2                       3
# 1                         3                       3                       5
# 2                         3                       2                       3
# 3                         3                       2                       3
# 4                         3                       2                       3
# 5                         3                       2                       3
# 6                         3                       3                       5
# 7                         3                       2                       3
# 8                         3                       2                       3
# 9                         3                       2                       3
# 10                        3                       3                       5
# 11                        3                       3                       5
# 12                        3                       2                       3
# 13                        3                       3                       5
# 14                        3                       3                       5
# 15                        3                       2                       3
# 16                        3                       3                       5
# 17                        3                       2                       3
# 18                        3                       3                       5
# 19                        3                       2                       3
#
#     hands  raintrousers  socks  shoes
# 0       3             0      3      3
# 1       3             0      3      3
# 2       3             0      3      3
# 3       3             0      3      3
# 4       3             0      3      3
# 5       3             0      3      3
# 6       3             0      3      3
# 7       3             0      3      3
# 8       3             0      3      3
# 9       3             0      3      3
# 10      3             0      3      3
# 11      3             0      3      3
# 12      3             0      3      3
# 13      3             0      3      3
# 14      3             0      3      3
# 15      3             0      3      3
# 16      3             0      3      3
# 17      3             0      3      3
# 18      3             0      3      3
# 19      3             0      3      3

# %%
add_dummy(test2)
# Out:
#     location                       time heaviness_of_trip  heat_preference  \
# 0   Freiburg 2022-01-26 23:58:23.600754              hard                0
# 1   Freiburg 2022-01-26 18:58:23.602746              easy                0
# 2   Freiburg 2022-01-26 22:58:23.612736              hard                0
# 3   Freiburg 2022-01-26 20:58:23.621696              easy                0
# 4   Freiburg 2022-01-26 23:58:23.631668              hard                0
# 5   Freiburg 2022-01-26 22:58:23.635657              hard                0
# 6   Freiburg 2022-01-26 22:58:23.646628              easy                0
# 7   Freiburg 2022-01-26 18:58:23.699486              hard                0
# 8   Freiburg 2022-01-26 23:58:23.711456              hard                0
# 9   Freiburg 2022-01-26 19:58:23.728411            normal                0
# 10  Freiburg 2022-01-26 19:58:23.742382            normal                0
# 11  Freiburg 2022-01-26 20:58:23.771294            normal                0
# 12  Freiburg 2022-01-26 22:58:23.777278              hard                0
# 13  Freiburg 2022-01-26 22:58:23.788249              easy                0
# 14  Freiburg 2022-01-26 22:58:23.794234            normal                0
# 15  Freiburg 2022-01-26 21:58:23.809195              easy                0
# 16  Freiburg 2022-01-26 21:58:23.817173            normal                0
# 17  Freiburg 2022-01-26 22:58:23.823158              hard                0
# 18  Freiburg 2022-01-26 21:58:23.829139              hard                0
# 19  Freiburg 2022-01-26 23:58:23.834126              hard                0
#
#    sex weather temperature  windspeed  headwear  sunglasses  neck  singlet  \
# 0    m  Clouds       -1.53       1.38         3           0     1        0
# 1    m     Fog       -1.28       1.03         1           0     2        1
# 2    m  Clouds       -1.53       1.38         2           0     3        1
# 3    m  Clouds       -1.35       1.41         3           0     3        0
# 4    m  Clouds       -1.53       1.38         4           1     3        0
# 5    m  Clouds       -1.53       1.38         1           1     1        1
# 6    m  Clouds       -1.53       1.38         1           1     2        1
# 7    m     Fog       -1.28       1.03         2           0     1        1
# 8    m  Clouds       -1.53       1.38         4           0     1        0
# 9    m     Fog       -1.28       1.03         4           1     3        0
# 10   m     Fog       -1.28       1.03         3           1     2        1
# 11   m  Clouds       -1.35       1.41         1           1     1        1
# 12   m  Clouds       -1.53       1.38         3           0     1        0
# 13   m  Clouds       -1.53       1.38         3           1     3        0
# 14   m  Clouds       -1.53       1.38         4           0     2        0
# 15   m  Clouds       -1.35       1.41         2           0     2        0
# 16   m  Clouds       -1.35       1.41         3           0     3        0
# 17   m  Clouds       -1.53       1.38         4           0     1        1
# 18   m  Clouds       -1.35       1.41         3           0     3        0
# 19   m  Clouds       -1.53       1.38         2           1     1        1
#
#     shirt  upper_body_second_layer  upper_body_third_layer  \
# 0       1                        2                       3
# 1       0                        3                       2
# 2       1                        3                       3
# 3       0                        2                       1
# 4       1                        3                       3
# 5       1                        2                       3
# 6       0                        3                       1
# 7       0                        3                       2
# 8       1                        1                       1
# 9       1                        1                       2
# 10      0                        2                       2
# 11      0                        2                       3
# 12      0                        3                       1
# 13      1                        3                       1
# 14      1                        2                       2
# 15      1                        1                       1
# 16      1                        3                       2
# 17      0                        3                       3
# 18      1                        3                       3
# 19      1                        1                       3
#
#     upper_body_outer_layer  hands  raintrousers  socks  shoes
# 0                        4      1             0      1      3
# 1                        1      2             1      1      3
# 2                        4      3             1      1      1
# 3                        2      1             1      2      3
# 4                        4      1             1      1      2
# 5                        2      3             1      2      1
# 6                        5      3             0      2      1
# 7                        1      3             1      1      3
# 8                        1      3             0      2      1
# 9                        5      3             0      1      1
# 10                       1      2             1      1      3
# 11                       3      3             0      2      3
# 12                       5      1             0      1      1
# 13                       1      1             1      1      1
# 14                       5      2             1      2      2
# 15                       2      2             0      2      1
# 16                       5      2             1      1      2
# 17                       4      2             1      2      3
# 18                       4      1             1      2      2
# 19                       1      1             1      1      3

# %% [markdown]
# <hr style="border:2px solid gray"> </hr>
#
# ## Part 6: Model evaluation
# How do you evaluate the quality of the decisions? Assume you get true label values.
# Which evaluation metrics do you use? Which plots would be interesting?
#
# Generating a Input dataset for User to evaluate with 15 datapoints
# Ask Matze for his clothing choices.
# and give our recommendation on the same Datapoints
# and ask Matze for his scoring of our recommendation

# %%
def generate_evaluationset():
    df=input_generator()
    df.at[0,'heat_preference']=0
    df.at[0,'sex']='m'
    for t in range(14): #a Trips today (it is asking for one person, so the sex, the heat preference and the ocation ist not changing)
        df=df.append(input_generator(),ignore_index = True)
        df.at[t+1,'heat_preference']=0
        df.at[t+1,'sex']='m'
    return df

# %%
evaluation_technical=weather(generate_evaluationset())

# %%
print(evaluation_technical)
evaluation_user=get_clothing_output_rbm(evaluation_technical)
print(evaluation_user)
# Out:
#           location                       time heaviness_of_trip  \
# 0        Kathmandu 2022-01-26 20:05:41.091290            normal
# 1              Rom 2022-01-26 19:05:41.094283            normal
# 2   Rio de Janeiro 2022-01-26 19:05:41.099630              hard
# 3   Rio de Janeiro 2022-01-26 23:05:41.103260            normal
# 4        Barcelona 2022-01-26 19:05:41.108245              easy
# 5        Singapore 2022-01-26 20:05:41.116771              easy
# 6        Melbourne 2022-01-26 23:05:41.121746              easy
# 7        Melbourne 2022-01-26 20:05:41.124728              easy
# 8        Singapore 2022-01-26 19:05:41.126723            normal
# 9        Kathmandu 2022-01-26 19:05:41.129719            normal
# 10          Moskau 2022-01-26 20:05:41.134702            normal
# 11       Kathmandu 2022-01-26 22:05:41.137695              easy
# 12             Rom 2022-01-26 22:05:41.157161              easy
# 13       Kathmandu 2022-01-26 19:05:41.165657              hard
# 14             Rom 2022-01-26 21:05:41.175625              hard
#
#     heat_preference sex weather temperature  windspeed
# 0                 0   m  Clouds        5.44       0.67
# 1                 0   m  Clouds        9.43       2.06
# 2                 0   m   Clear       33.28       3.24
# 3                 0   m   Clear       29.24       1.89
# 4                 0   m   Clear       11.56       5.66
# 5                 0   m  Clouds       25.24       4.66
# 6                 0   m    Rain       18.81       5.51
# 7                 0   m    Rain       18.53       4.99
# 8                 0   m  Clouds       25.57       2.57
# 9                 0   m  Clouds        6.12       1.54
# 10                0   m  Clouds       -6.88       1.31
# 11                0   m  Clouds        5.44       0.67
# 12                0   m  Clouds        8.42       1.82
# 13                0   m  Clouds        6.12       1.54
# 14                0   m  Clouds        8.42       1.82
#           location                       time heaviness_of_trip  \
# 0        Kathmandu 2022-01-26 20:05:41.091290            normal
# 1              Rom 2022-01-26 19:05:41.094283            normal
# 2   Rio de Janeiro 2022-01-26 19:05:41.099630              hard
# 3   Rio de Janeiro 2022-01-26 23:05:41.103260            normal
# 4        Barcelona 2022-01-26 19:05:41.108245              easy
# 5        Singapore 2022-01-26 20:05:41.116771              easy
# 6        Melbourne 2022-01-26 23:05:41.121746              easy
# 7        Melbourne 2022-01-26 20:05:41.124728              easy
# 8        Singapore 2022-01-26 19:05:41.126723            normal
# 9        Kathmandu 2022-01-26 19:05:41.129719            normal
# 10          Moskau 2022-01-26 20:05:41.134702            normal
# 11       Kathmandu 2022-01-26 22:05:41.137695              easy
# 12             Rom 2022-01-26 22:05:41.157161              easy
# 13       Kathmandu 2022-01-26 19:05:41.165657              hard
# 14             Rom 2022-01-26 21:05:41.175625              hard
#
#     heat_preference sex weather temperature  windspeed  headwear  sunglasses  \
# 0                 0   m  Clouds        5.44       0.67         2           0
# 1                 0   m  Clouds        9.43       2.06         2           0
# 2                 0   m   Clear       33.28       3.24         1           1
# 3                 0   m   Clear       29.24       1.89         1           1
# 4                 0   m   Clear       11.56       5.66         2           1
# 5                 0   m  Clouds       25.24       4.66         1           0
# 6                 0   m    Rain       18.81       5.51         1           0
# 7                 0   m    Rain       18.53       4.99         1           0
# 8                 0   m  Clouds       25.57       2.57         1           0
# 9                 0   m  Clouds        6.12       1.54         2           0
# 10                0   m  Clouds       -6.88       1.31         3           0
# 11                0   m  Clouds        5.44       0.67         2           0
# 12                0   m  Clouds        8.42       1.82         2           0
# 13                0   m  Clouds        6.12       1.54         2           0
# 14                0   m  Clouds        8.42       1.82         1           0
#
#     neck  shirt  singlet  upper_body_second_layer  upper_body_third_layer  \
# 0      3      0        1                        3                       1
# 1      3      0        1                        3                       1
# 2      1      1        0                        1                       1
# 3      1      1        0                        1                       1
# 4      2      0        1                        2                       2
# 5      1      1        0                        2                       1
# 6      2      1        0                        3                       1
# 7      2      1        0                        3                       1
# 8      1      1        0                        1                       1
# 9      3      0        1                        3                       1
# 10     3      0        1                        3                       3
# 11     3      0        1                        3                       1
# 12     3      0        1                        3                       1
# 13     3      0        1                        3                       1
# 14     3      1        0                        2                       2
#
#     upper_body_outer_layer  hands  raintrousers  socks  shoes
# 0                        5      2             0      2      3
# 1                        5      1             0      2      2
# 2                        1      1             0      2      1
# 3                        1      1             0      2      1
# 4                        3      1             0      2      2
# 5                        1      1             0      2      1
# 6                        4      1             1      2      4
# 7                        4      1             1      2      4
# 8                        1      1             0      2      1
# 9                        5      2             0      2      3
# 10                       5      3             0      3      3
# 11                       5      2             0      2      3
# 12                       5      2             0      2      3
# 13                       5      1             0      2      2
# 14                       1      1             0      2      2

# %%
evaluation_user.to_csv('evaluation_user.csv', index=False)

# %% [markdown]
# <hr style="border:2px solid gray"> </hr>
#
# ## Part 7: Output concatenating
# get_clothing(df) function to give out 3 Dataframes (one for wearing now, one for the backpack and one what to wear at which trip).<p>
# Functions recommendation_df(df) and recommendation_json(js) are translating the input (either from a Dataframe or a Json) into a Json for the Flask API.

# %%
# get three lists for to wear now and to bring in the backpack and a full DF what to wear at which trip
def get_clothing(df):
    dic=['headwear','sunglasses','neck','singlet','shirt','upper_body_second_layer','upper_body_third_layer','upper_body_outer_layer','hands','raintrousers','socks','shoes'] # all columns
    oneisnone=['headwear','neck','upper_body_second_layer','upper_body_third_layer','upper_body_outer_layer','hands'] # all colums where 1 is the lowest possible output
    ##wear_now is the first clothing set from the first input beside when shoes and jacket are to big, they have to be wear them 
    wear_now=df.iloc[0:1].copy()
    ##in the backpack is all the other necessary clothes
    backpack_help=df.iloc[:,8:].copy()
    backpack=backpack_help.iloc[0:0].copy() # empty DF with column names
    for i in dic:
        if backpack_help[i].unique().max()==0|((i in oneisnone) & backpack_help[i].unique().max()==1): #if the maximum of the category is not wear any, stop here
            backpack.at[0,i]=None
        else:
            z=0
            while z<backpack_help[i].nunique():
                if backpack_help[i].unique()[z]!=0: #if the the newest item of the category is not to wear any, skip it
                    if ((i in oneisnone) & backpack_help[i].unique()[z]!=1):
                        backpack.at[z,i]=backpack_help[i].unique()[z]
                z=z+1
    ##if shoes or the outerlayer are bigger in the backpack we gonna wear the biggest one, so the backpack won't get to full
    if backpack_help['shoes'].unique().max()> wear_now['shoes'][0]:
        wear_now.at[0,'shoes']=backpack_help['shoes'].unique().max()
    backpack.at[:,'shoes']=None
    if backpack_help['upper_body_outer_layer'].unique().max()> wear_now['upper_body_outer_layer'][0]:
        wear_now.at[0,'upper_body_outer_layer']=backpack_help['upper_body_outer_layer'].unique().max()
    backpack.at[:,'upper_body_outer_layer']=None  
    backpack=backpack.replace({np.nan: None})
    #Ouput of all Clothing Sets in every trip, shoes and outerlayer must be the same as in the first trip
    clothing_per_trip=df
    clothing_per_trip.at[:,'shoes']=wear_now['shoes'][0]
    clothing_per_trip.at[:,'upper_body_outer_layer']=wear_now['upper_body_outer_layer'][0]

    return wear_now, backpack, clothing_per_trip

# %%
def recommendation_json(js):
    json_inp= pd.read_json(js, orient='index',convert_dates=['time'])  
    rec_dfs= get_clothing(get_clothing_output_rbm(weather(input_cleaning(json_inp))))
    rec_js= '{"clothes":{"now":'+rec_dfs[0].to_json(orient="records")
    rec_js= rec_js+',"backpack":'+rec_dfs[1].apply(lambda x: [x.dropna()], axis=1).to_json() # drop the nan from df
    rec_js= rec_js+',"perTrip":'+rec_dfs[2].to_json(orient="index")+'}}'
    return rec_js

# %%
def recommendation_df(df):
    rec_dfs= get_clothing(get_clothing_output_rbm(weather(input_cleaning(df))))
    rec_js= '{"clothes":{"now":'+rec_dfs[0].to_json(orient="records")
    rec_js= rec_js+',"backpack":'+rec_dfs[1].apply(lambda x: [x.dropna()], axis=1).to_json()#(orient="columns")
    rec_js= rec_js+',"perTrip":'+rec_dfs[2].to_json(orient="index")+'}}'
    return rec_js

# %%
recommendation_df(test3)
# Out:
# '{"clothes":{"now":[{"location":"Melbourne","time":1642975344670,"heaviness_of_trip":"normal","heat_preference":5,"sex":"d","weather":"Clouds","temperature":14.48,"windspeed":4.26,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes":2}],"backpack":{"0":[{"shirt":1.0,"upper_body_second_layer":2.0,"upper_body_third_layer":2.0,"socks":2.0}]},"perTrip":{"0":{"location":"Melbourne","time":1642975344670,"heaviness_of_trip":"normal","heat_preference":5,"sex":"d","weather":"Clouds","temperature":14.48,"windspeed":4.26,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes":2},"1":{"location":"Melbourne","time":1642971744671,"heaviness_of_trip":"easy","heat_preference":5,"sex":"d","weather":"Clouds","temperature":14.48,"windspeed":4.26,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes":2},"2":{"location":"Melbourne","time":1642964544676,"heaviness_of_trip":"hard","heat_preference":5,"sex":"d","weather":"Clouds","temperature":12.65,"windspeed":5.14,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes":2},"3":{"location":"Melbourne","time":1642964544681,"heaviness_of_trip":"easy","heat_preference":5,"sex":"d","weather":"Clouds","temperature":12.65,"windspeed":5.14,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes":2},"4":{"location":"Melbourne","time":1642968144683,"heaviness_of_trip":"easy","heat_preference":5,"sex":"d","weather":"Clouds","temperature":14.48,"windspeed":4.26,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes":2},"5":{"location":"Melbourne","time":1642971744686,"heaviness_of_trip":"normal","heat_preference":5,"sex":"d","weather":"Clouds","temperature":14.48,"windspeed":4.26,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes":2},"6":{"location":"Melbourne","time":1642978944691,"heaviness_of_trip":"normal","heat_preference":5,"sex":"d","weather":"Clouds","temperature":13.73,"windspeed":4.5,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes":2},"7":{"location":"Melbourne","time":1642964544695,"heaviness_of_trip":"normal","heat_preference":5,"sex":"d","weather":"Clouds","temperature":12.65,"windspeed":5.14,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes":2},"8":{"location":"Melbourne","time":1642971744699,"heaviness_of_trip":"hard","heat_preference":5,"sex":"d","weather":"Clouds","temperature":14.48,"windspeed":4.26,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":1,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes":2},"9":{"location":"Melbourne","time":1642978944702,"heaviness_of_trip":"normal","heat_preference":5,"sex":"d","weather":"Clouds","temperature":13.73,"windspeed":4.5,"headwear":1,"sunglasses":0,"neck":1,"shirt":1,"singlet":0,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":1,"hands":1,"raintrousers":0,"socks":2,"shoes": ...

# %%
print(get_clothing(test2))

print(get_clothing(test2)[0].to_json(orient="records"))
print(get_clothing(test2)[1].to_json(orient="columns"))
print(get_clothing(test2)[2].to_json(orient="index"))

# res = clothing_per_trip.to_json(orient="records")
#  parsed = json.loads(res)
#   print(json.dumps(parsed,indent=1))
# Out:
# (  location                       time heaviness_of_trip  heat_preference sex  \
# 0   Berlin 2022-01-23 22:02:17.908702            normal                1   d
#
#   weather temperature  windspeed  headwear  sunglasses  neck  singlet  shirt  \
# 0  Clouds        5.61       1.64         2           0     2        0      0
#
#    upper_body_second_layer  upper_body_third_layer  upper_body_outer_layer  \
# 0                        1                       3                       5
#
#    hands  raintrousers  socks  shoes
# 0      3             0      2      3  ,   headwear sunglasses  neck singlet shirt upper_body_second_layer  \
# 0      2.0       None   2.0    None  None                    None
# 1      4.0        1.0  None     1.0   1.0                    None
# 2     None       None  None    None  None                     2.0
# 4     None       None  None    None  None                    None
#
#   upper_body_third_layer upper_body_outer_layer hands raintrousers socks shoes
# 0                   None                   None  None         None   2.0  None
# 1                    2.0                   None   2.0          1.0   1.0  None
# 2                   None                   None  None         None  None  None
# 4                   None                   None  None         None  None  None  ,    location                       time heaviness_of_trip  heat_preference sex  \
# 0    Berlin 2022-01-23 22:02:17.908702            normal                1   d
# 1    Berlin 2022-01-23 23:02:17.908702              hard                1   d
# 2    Berlin 2022-01-23 19:02:17.908702              hard                1   d
# 3    Berlin 2022-01-23 21:02:17.924280              easy                1   d
# 4    Berlin 2022-01-23 20:02:17.924280              easy                1   d
# 5    Berlin 2022-01-23 19:02:17.924280            normal                1   d
# 6    Berlin 2022-01-23 22:02:17.924280              hard                1   d
# 7    Berlin 2022-01-23 23:02:17.924280              easy                1   d
# 8    Berlin 2022-01-23 23:02:17.924280            normal                1   d
# 9    Berlin 2022-01-23 22:02:17.924280            normal                1   d
# 10   Berlin 2022-01-23 22:02:17.924280            normal                1   d
# 11   Berlin 2022-01-23 22:02:17.924280              hard                1   d
# 12   Berlin 2022-01-23 18:02:17.939900            normal                1   d
# 13   Berlin 2022-01-23 20:02:17.939900              hard                1   d
# 14   Berlin 2022-01-23 19:02:17.939900              hard                1   d
# 15   Berlin 2022-01-23 23:02:17.946439            normal                1   d
# 16   Berlin 2022-01-23 23:02:17.946439              hard                1   d
# 17   Berlin 2022-01-23 20:02:17.946439            normal                1   d
# 18   Berlin 2022-01-23 19:02:17.946439              hard                1   d
# 19   Berlin 2022-01-23 21:02:17.946439              easy                1   d
#
#     weather temperature  windspeed  headwear  sunglasses  neck  singlet  \
# 0    Clouds        5.61       1.64         2           0     2        0
# 1    Clouds        5.21       1.48         4           0     3        1
# 2   Drizzle        5.93       2.68         1           0     1        1
# 3    Clouds        5.61       1.64         3           1     1        0
# 4    Clouds        5.61       1.64         4           1     1        0
# 5   Drizzle        5.93       2.68         4           0     2        1
# 6    Clouds        5.61       1.64         3           0     3        1
# 7    Clouds        5.21       1.48         3           0     1        0
# 8    Clouds        5.21       1.48         1           1     3        1
# 9    Clouds        5.61       1.64         1           1     2        0
# 10   Clouds        5.61       1.64         4           1     1        1
# 11   Clouds        5.61       1.64         3           0     2        0
# 12  Drizzle        5.93       2.68         3           0     3        0
# 13   Clouds        5.61       1.64         3           1     2        1
# 14  Drizzle        5.93       2.68         4           1     3        0
# 15   Clouds        5.21       1.48         1           0     3        0
# 16   Clouds        5.21       1.48         3           0     3        1
# 17   Clouds        5.61       1.64         2           1     1        1
# 18  Drizzle        5.93       2.68         4           1     1        0
# 19   Clouds        5.61       1.64         2           1     1        1
#
#     shirt  upper_body_second_layer  upper_body_third_layer  \
# 0       0                        1                       3
# 1       0                        3                       2
# 2       1                        3                       2
# 3       1                        2                       2
# 4       0                        2                       3
# 5       0                        3                       3
# 6       1                        1                       3
# 7       1                        1                       3
# 8       1                        2                       1
# 9       1                        3                       2
# 10      1                        3                       3
# 11      0                        2                       2
# 12      0                        1                       1
# 13      0                        2                       2
# 14      0                        3                       1
# 15      0                        2                       1
# 16      0                        1                       3
# 17      0                        3                       1
# 18      0                        2                       1
# 19      0                        2                       3
#
#     upper_body_outer_layer  hands  raintrousers  socks  shoes
# 0                        5      3             0      2      3
# 1                        5      2             1      2      3
# 2                        5      3             1      2      3
# 3                        5      3             1      1      3
# 4                        5      3             0      1      3
# 5                        5      2             1      2      3
# 6                        5      3             0      1      3
# 7                        5      1             1      2      3
# 8                        5      2             1      1      3
# 9                        5      1             0      1      3
# 10                       5      3             0      1      3
# 11                       5      1             0      1      3
# 12                       5      2             1      1      3
# 13                       5      1             0      2      3
# 14                       5      1             0      1      3
# 15                       5      2             0      1      3
# 16                       5      1             0      1      3
# 17                       5      3             1      1      3
# 18                       5      2             1      1      3
# 19                       5      1             1      2      3  )
# [{"location":"Berlin","time":1642975337908,"heaviness_of_trip":"normal","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.61,"windspeed":1.64,"headwear":2,"sunglasses":0,"neck":2,"singlet":0,"shirt":0,"upper_body_second_layer":1,"upper_body_third_layer":3,"upper_body_outer_layer":5,"hands":3,"raintrousers":0,"socks":2,"shoes":3}]
# {"headwear":{"0":2.0,"1":4.0,"2":null},"sunglasses":{"0":null,"1":1.0,"2":null},"neck":{"0":2.0,"1":null,"2":null},"singlet":{"0":null,"1":1.0,"2":null},"shirt":{"0":null,"1":1.0,"2":null},"upper_body_second_layer":{"0":null,"1":null,"2":2.0},"upper_body_third_layer":{"0":null,"1":2.0,"2":null},"upper_body_outer_layer":{"0":null,"1":null,"2":null},"hands":{"0":null,"1":2.0,"2":null},"raintrousers":{"0":null,"1":1.0,"2":null},"socks":{"0":2.0,"1":1.0,"2":null},"shoes":{"0":null,"1":null,"2":null}}
# {"0":{"location":"Berlin","time":1642975337908,"heaviness_of_trip":"normal","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.61,"windspeed":1.64,"headwear":2,"sunglasses":0,"neck":2,"singlet":0,"shirt":0,"upper_body_second_layer":1,"upper_body_third_layer":3,"upper_body_outer_layer":5,"hands":3,"raintrousers":0,"socks":2,"shoes":3},"1":{"location":"Berlin","time":1642978937908,"heaviness_of_trip":"hard","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.21,"windspeed":1.48,"headwear":4,"sunglasses":0,"neck":3,"singlet":1,"shirt":0,"upper_body_second_layer":3,"upper_body_third_layer":2,"upper_body_outer_layer":5,"hands":2,"raintrousers":1,"socks":2,"shoes":3},"2":{"location":"Berlin","time":1642964537908,"heaviness_of_trip":"hard","heat_preference":1,"sex":"d","weather":"Drizzle","temperature":5.93,"windspeed":2.68,"headwear":1,"sunglasses":0,"neck":1,"singlet":1,"shirt":1,"upper_body_second_layer":3,"upper_body_third_layer":2,"upper_body_outer_layer":5,"hands":3,"raintrousers":1,"socks":2,"shoes":3},"3":{"location":"Berlin","time":1642971737924,"heaviness_of_trip":"easy","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.61,"windspeed":1.64,"headwear":3,"sunglasses":1,"neck":1,"singlet":0,"shirt":1,"upper_body_second_layer":2,"upper_body_third_layer":2,"upper_body_outer_layer":5,"hands":3,"raintrousers":1,"socks":1,"shoes":3},"4":{"location":"Berlin","time":1642968137924,"heaviness_of_trip":"easy","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.61,"windspeed":1.64,"headwear":4,"sunglasses":1,"neck":1,"singlet":0,"shirt":0,"upper_body_second_layer":2,"upper_body_third_layer":3,"upper_body_outer_layer":5,"hands":3,"raintrousers":0,"socks":1,"shoes":3},"5":{"location":"Berlin","time":1642964537924,"heaviness_of_trip":"normal","heat_preference":1,"sex":"d","weather":"Drizzle","temperature":5.93,"windspeed":2.68,"headwear":4,"sunglasses":0,"neck":2,"singlet":1,"shirt":0,"upper_body_second_layer":3,"upper_body_third_layer":3,"upper_body_outer_layer":5,"hands":2,"raintrousers":1,"socks":2,"shoes":3},"6":{"location":"Berlin","time":1642975337924,"heaviness_of_trip":"hard","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.61,"windspeed":1.64,"headwear":3,"sunglasses":0,"neck":3,"singlet":1,"shirt":1,"upper_body_second_layer":1,"upper_body_third_layer":3,"upper_body_outer_layer":5,"hands":3,"raintrousers":0,"socks":1,"shoes":3},"7":{"location":"Berlin","time":1642978937924,"heaviness_of_trip":"easy","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.21,"windspeed":1.48,"headwear":3,"sunglasses":0,"neck":1,"singlet":0,"shirt":1,"upper_body_second_layer":1,"upper_body_third_layer":3,"upper_body_outer_layer":5,"hands":1,"raintrousers":1,"socks":2,"shoes":3},"8":{"location":"Berlin","time":1642978937924,"heaviness_of_trip":"normal","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.21,"windspeed":1.48,"headwear":1,"sunglasses":1,"neck":3,"singlet":1,"shirt":1,"upper_body_second_layer":2,"upper_body_third_layer":1,"upper_body_outer_layer":5,"hands":2,"raintrousers":1,"socks":1,"shoes":3},"9":{"location":"Berlin","time":1642975337924,"heaviness_of_trip":"normal","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.61,"windspeed":1.64,"headwear":1,"sunglasses":1,"neck":2,"singlet":0,"shirt":1,"upper_body_second_layer":3,"upper_body_third_layer":2,"upper_body_outer_layer":5,"hands":1,"raintrousers":0,"socks":1,"shoes":3},"10":{"location":"Berlin","time":1642975337924,"heaviness_of_trip":"normal","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.61,"windspeed":1.64,"headwear":4,"sunglasses":1,"neck":1,"singlet":1,"shirt":1,"upper_body_second_layer":3,"upper_body_third_layer":3,"upper_body_outer_layer":5,"hands":3,"raintrousers":0,"socks":1,"shoes":3},"11":{"location":"Berlin","time":1642975337924,"heaviness_of_trip":"hard","heat_preference":1,"sex":"d","weather":"Clouds","temperature":5.61,"windspeed":1.64,"headwear" ...
